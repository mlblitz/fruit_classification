# %%
# Importing modules 
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt

import cv2
import tensorflow as tf

from keras.utils import to_categorical
from keras.layers import Conv2D,MaxPooling2D,BatchNormalization,Activation,Dense,Flatten
from keras.models import Sequential

from sklearn.model_selection import train_test_split

import seaborn as sn
import numpy as np

from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve, RocCurveDisplay

from sklearn import metrics

from keras.utils import to_categorical
from keras.layers import Conv2D,MaxPooling2D,BatchNormalization,Activation,Dense,Flatten
from keras.models import Sequential

from sklearn.model_selection import train_test_split

import seaborn as sn
import numpy as np

from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve, RocCurveDisplay

from sklearn import metrics

np.random.seed(1)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
train_images = []       
train_labels = []
shape = (224,224)  
train_path ='/content/drive/Shareddrives/ECE 539/train'

for filename in os.listdir(train_path):
    if filename.split('.')[1] == 'jpg':
        imgResize = cv2.imread(os.path.join(train_path,filename))
        imgRotate = cv2.imread(os.path.join(train_path,filename))
        
        # Spliting file names and storing the labels for image in list
        train_labels.append(filename.split('_')[0])
        train_labels.append(filename.split('_')[0])
        
        # Resize all images to a specific shape
        imgResize = cv2.resize(imgResize,shape)

        # Rotate all images
        imgRotate = cv2.resize(imgResize,shape)
        imgRotate = cv2.rotate(imgRotate, cv2.ROTATE_90_CLOCKWISE)
        
        train_images.append(imgRotate)
        train_images.append(imgResize)
        
train_labels = pd.get_dummies(train_labels).values

# Converting train_images to array
train_images = np.array(train_images)


# Splitting Training data into train and validation dataset
X_train,X_val,y_train,y_val = train_test_split(train_images,train_labels,random_state=1)

# %%
test_images = []
test_labels = []
shape = (224,224)
test_path = "/content/drive/Shareddrives/ECE 539/test"

for filename in os.listdir(test_path):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(test_path,filename))
        
        # Spliting file names and storing the labels for image in list
        test_labels.append(filename.split('_')[0])
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
        
        test_images.append(img)
        
# Converting test_images to array
X_test = np.array(test_images)
y_test = pd.get_dummies(test_labels).values

# %%
print('Train: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Val  : X=%s, y=%s' % (X_val.shape, y_val.shape))
print('Test : X=%s, y=%s' % (X_test.shape, y_test.shape))
# Out:
# Train: X=(360, 224, 224, 3), y=(360, 4)
# Val  : X=(120, 224, 224, 3), y=(120, 4)
# Test : X=(60, 224, 224, 3), y=(60, 4)

# %%
net = Sequential()
net.add(Conv2D(32, (3, 3), padding='same', input_shape=(224, 224, 3)))
net.add(BatchNormalization())
net.add(Activation('relu'))

net.add(MaxPooling2D((2, 2),strides=2))

net.add(Conv2D(30, (3, 3), padding='same'))
net.add(BatchNormalization())
net.add(Activation('relu'))

net.add(MaxPooling2D((2, 2),strides=2))

net.add(Conv2D(30, (3, 3), padding='same'))
net.add(BatchNormalization())
net.add(Activation('relu'))

net.add(Flatten())

net.add(Dense(20,activation='relu'))
net.add(Dense(15,activation='relu'))
net.add(Dense(4,activation = 'softmax'))

# %%
# Creating a Sequential model
# net= Sequential()
# net.add(Conv2D(kernel_size=(3,3), filters=32, activation='relu', input_shape=(200,200,3,)))
# net.add(Conv2D(filters=30,kernel_size = (3,3),activation='relu'))
# net.add(MaxPooling2D(2,2))
# net.add(Conv2D(filters=30,kernel_size = (3,3),activation='relu'))
# net.add(MaxPooling2D(2,2))
# net.add(Conv2D(filters=30,kernel_size = (3,3),activation='relu'))

# net.add(Flatten())

# net.add(Dense(20,activation='relu'))
# net.add(Dense(15,activation='relu'))
# net.add(Dense(4,activation = 'softmax'))

# # net.compile(
# #               loss='categorical_crossentropy', 
# #               metrics=['acc'],
# #               optimizer='adam'
# #              )

# %%
net.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 224, 224, 32)      896
#
#  batch_normalization_15 (Bat  (None, 224, 224, 32)     128
#  chNormalization)
#
#  activation_15 (Activation)  (None, 224, 224, 32)      0
#
#  max_pooling2d_10 (MaxPoolin  (None, 112, 112, 32)     0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 112, 112, 30)      8670
#
#  batch_normalization_16 (Bat  (None, 112, 112, 30)     120
#  chNormalization)
#
#  activation_16 (Activation)  (None, 112, 112, 30)      0
#
#  max_pooling2d_11 (MaxPoolin  (None, 56, 56, 30)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 56, 56, 30)        8130
#
#  batch_normalization_17 (Bat  (None, 56, 56, 30)       120
#  chNormalization)
#
#  activation_17 (Activation)  (None, 56, 56, 30)        0
#
#  flatten_5 (Flatten)         (None, 94080)             0
#
#  dense_15 (Dense)            (None, 20)                1881620
#
#  dense_16 (Dense)            (None, 15)                315
#
#  dense_17 (Dense)            (None, 4)                 64
#
# =================================================================
# Total params: 1,900,063
# Trainable params: 1,899,879
# Non-trainable params: 184
# _________________________________________________________________

# %%
# history = net.fit(X_train,y_train,epochs=50,batch_size=50,validation_data=(X_val,y_val))

# %%
# # Hyperparameters
# lr = 0.1
# mom = 0.9 
ep = 50
bs = 50

# %%
# # compile and fit the keras model
#from tensorflow.keras.optimizers import Adam
# # opt = SGD(learning_rate=lr, momentum=mom)
#adam = Adam(learning_rate=0.001)
net.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')


# insert model check point call back
checkpoint_filepath = 'tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = net.fit(X_train, y_train, epochs=ep, batch_size=bs, validation_data=(X_val,y_val) , verbose=1, callbacks=[model_checkpoint_callback])
# The model weights (that are considered the best) are loaded into the model.
net.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 2s 116ms/step - loss: 7.7023 - accuracy: 0.3139 - val_loss: 32.4432 - val_accuracy: 0.3667
# Epoch 2/50
# 8/8 [==============================] - 1s 73ms/step - loss: 4.2716 - accuracy: 0.6528 - val_loss: 15.6968 - val_accuracy: 0.3667
# Epoch 3/50
# 8/8 [==============================] - 1s 84ms/step - loss: 2.0052 - accuracy: 0.7722 - val_loss: 7.4275 - val_accuracy: 0.4500
# Epoch 4/50
# 8/8 [==============================] - 1s 82ms/step - loss: 1.2922 - accuracy: 0.8056 - val_loss: 8.6447 - val_accuracy: 0.4917
# Epoch 5/50
# 8/8 [==============================] - 1s 81ms/step - loss: 0.8188 - accuracy: 0.7583 - val_loss: 2.3204 - val_accuracy: 0.5333
# Epoch 6/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.4796 - accuracy: 0.8278 - val_loss: 4.6175 - val_accuracy: 0.3333
# Epoch 7/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.3988 - accuracy: 0.9083 - val_loss: 5.8222 - val_accuracy: 0.4250
# Epoch 8/50
# 8/8 [==============================] - 1s 84ms/step - loss: 0.3224 - accuracy: 0.8861 - val_loss: 1.9673 - val_accuracy: 0.6000
# Epoch 9/50
# 8/8 [==============================] - 1s 82ms/step - loss: 0.2664 - accuracy: 0.8944 - val_loss: 0.9763 - val_accuracy: 0.7667
# Epoch 10/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.2673 - accuracy: 0.8750 - val_loss: 2.5738 - val_accuracy: 0.6083
# Epoch 11/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.2124 - accuracy: 0.9222 - val_loss: 1.3337 - val_accuracy: 0.6917
# Epoch 12/50
# 8/8 [==============================] - 1s 82ms/step - loss: 0.2002 - accuracy: 0.9389 - val_loss: 0.5392 - val_accuracy: 0.8750
# Epoch 13/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1790 - accuracy: 0.9500 - val_loss: 0.5909 - val_accuracy: 0.7917
# Epoch 14/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.2163 - accuracy: 0.9111 - val_loss: 0.6068 - val_accuracy: 0.8333
# Epoch 15/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1673 - accuracy: 0.9333 - val_loss: 0.9467 - val_accuracy: 0.7333
# Epoch 16/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1395 - accuracy: 0.9667 - val_loss: 0.6174 - val_accuracy: 0.7750
# Epoch 17/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1095 - accuracy: 0.9806 - val_loss: 0.5516 - val_accuracy: 0.8167
# Epoch 18/50
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0811 - accuracy: 0.9806 - val_loss: 0.5064 - val_accuracy: 0.8833
# Epoch 19/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0857 - accuracy: 0.9806 - val_loss: 0.4502 - val_accuracy: 0.8417
# Epoch 20/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0608 - accuracy: 0.9917 - val_loss: 0.4933 - val_accuracy: 0.7500
# Epoch 21/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0455 - accuracy: 0.9917 - val_loss: 0.4797 - val_accuracy: 0.8417
# Epoch 22/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0393 - accuracy: 0.9889 - val_loss: 0.4779 - val_accuracy: 0.8833
# Epoch 23/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0327 - accuracy: 0.9889 - val_loss: 0.4511 - val_accuracy: 0.8750
# Epoch 24/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0348 - accuracy: 0.9889 - val_loss: 0.4707 - val_accuracy: 0.8417
# Epoch 25/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0535 - accuracy: 0.9806 - val_loss: 0.4399 - val_accuracy: 0.8583
# Epoch 26/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0395 - accuracy: 0.9917 - val_loss: 0.6182 - val_accuracy: 0.8250
# Epoch 27/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0307 - accuracy: 0.9889 - val_loss: 0.9313 - val_accuracy: 0.7750
# Epoch 28/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.8421 - val_accuracy: 0.7750
# Epoch 29/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0214 - accuracy: 0.9917 - val_loss: 0.5747 - val_accuracy: 0.8083
# Epoch 30/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0128 - accuracy: 0.9972 - val_loss: 0.4535 - val_accuracy: 0.8750
# Epoch 31/50
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0111 - accuracy: 0.9972 - val_loss: 0.3789 - val_accuracy: 0.9000
# Epoch 32/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0115 - accuracy: 0.9972 - val_loss: 0.4117 - val_accuracy: 0.8917
# Epoch 33/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4235 - val_accuracy: 0.8917
# Epoch 34/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0494 - accuracy: 0.9889 - val_loss: 1.4302 - val_accuracy: 0.6667
# Epoch 35/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0360 - accuracy: 0.9889 - val_loss: 1.0182 - val_accuracy: 0.7917
# Epoch 36/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0220 - accuracy: 0.9944 - val_loss: 0.9079 - val_accuracy: 0.8000
# Epoch 37/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.8982 - val_accuracy: 0.7917
# Epoch 38/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0125 - accuracy: 0.9972 - val_loss: 0.8024 - val_accuracy: 0.8000
# Epoch 39/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.6095 - val_accuracy: 0.8500
# Epoch 40/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.5353 - val_accuracy: 0.8583
# Epoch 41/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0244 - accuracy: 0.9944 - val_loss: 0.9877 - val_accuracy: 0.7750
# Epoch 42/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.2446 - accuracy: 0.9250 - val_loss: 4.3964 - val_accuracy: 0.5083
# Epoch 43/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0383 - accuracy: 0.9889 - val_loss: 0.7845 - val_accuracy: 0.8333
# Epoch 44/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0456 - accuracy: 0.9917 - val_loss: 1.3597 - val_accuracy: 0.7417
# Epoch 45/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0152 - accuracy: 0.9944 - val_loss: 1.1399 - val_accuracy: 0.7667
# Epoch 46/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0421 - accuracy: 0.9917 - val_loss: 0.5924 - val_accuracy: 0.8583
# Epoch 47/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1363 - accuracy: 0.9639 - val_loss: 1.9586 - val_accuracy: 0.6417
# Epoch 48/50
# 8/8 [==============================] - 1s 78ms/step - loss: 0.1006 - accuracy: 0.9639 - val_loss: 0.7664 - val_accuracy: 0.8333
# Epoch 49/50
# 8/8 [==============================] - 1s 79ms/step - loss: 0.1180 - accuracy: 0.9778 - val_loss: 1.0334 - val_accuracy: 0.8333
# Epoch 50/50
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0606 - accuracy: 0.9806 - val_loss: 2.4489 - val_accuracy: 0.6417

# %%
# You can visualize the results with a confusion matrix.
def plot_confusion_matrix(y_classified, y_true):
  # Compute confusion matrix
    c_mat = np.zeros((y_test.shape[1],y_test.shape[1]))
    for i in range(len(y_true)):
        c_mat[y_classified[i], y_true[i] ] += 1

    group_counts = ["{0:0.0f}".format(value) for value in c_mat.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in c_mat.flatten()/np.sum(c_mat)]
    labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(c_mat.shape[0], c_mat.shape[1])

    plt.figure(figsize=(12,10))
    sn.heatmap(c_mat, annot=labels, fmt='', cmap='rocket_r')
    plt.title("Confusion Matrix")
    plt.ylabel('Output Class')
    plt.xlabel('Target Class')

# %%
# Evaluate the trained model using keras built-in function
score = net.evaluate(X_test, y_test, verbose=1)
print("Test loss:", score[0])
print("Test accuracy:", score[1]) 

y_classified = np.argmax(net.predict(X_test), axis=1)
y_true =  np.argmax(y_test, axis=1)
# Compute the confusion matrix
print("Confusion matrix: \n", confusion_matrix(y_true, y_classified))

# plot confusion matrix
plot_confusion_matrix(y_classified, y_true)
# Out:
# 2/2 [==============================] - 0s 19ms/step - loss: 0.9813 - accuracy: 0.8500
# Test loss: 0.9812542200088501
# Test accuracy: 0.8500000238418579
# 2/2 [==============================] - 0s 17ms/step
# Confusion matrix:
#  [[17  1  0  1]
#  [ 1 17  0  0]
#  [ 1  4  0  0]
#  [ 0  1  0 17]]

# %%
# Compute the confusion matrix
print("Confusion matrix: \n", confusion_matrix(y_true, y_classified))
print("P(classification) =", np.round(accuracy_score(y_true, y_classified), 3))
# Out:
# Confusion matrix:
#  [[17  1  0  1]
#  [ 1 17  0  0]
#  [ 1  4  0  0]
#  [ 0  1  0 17]]
# P(classification) = 0.85

# %% [markdown]
# MCC

# %%
metrics.matthews_corrcoef(y_true, y_classified, sample_weight=None)
# Out:
# 0.7925269656756914

# %%
plt.figure(figsize = (16, 10))
classes = ['Apple', 'Banana', 'Mixed', 'Orange']

for i in range(len(classes)):
    y_true_sub = np.array([int(y == i) for y in y_true])
    y_class_sub = np.array([int(y == i) for y in y_classified])
    
    roc_auc = metrics.roc_auc_score(y_true_sub,y_class_sub)

    ax = plt.subplot(2, 3, i+1)
    ax.set_title(classes[i])
    ax.legend([f"Class: {classes[i]}", "Rest"])
    ax.set_xlabel(f"P(x = {classes[i]})")

    # Calculates the ROC Coordinates and plots the ROC Curves
    fpr, tpr, threshold = metrics.roc_curve(y_true_sub, y_class_sub)
    #plot_roc_curve(tpr, fpr, scatter = False, ax = ax_bottom)
    RocCurveDisplay.from_predictions(y_true_sub, y_class_sub, ax = ax)
    ax.set_title(f"ROC Curve {classes[i]} v Rest")
