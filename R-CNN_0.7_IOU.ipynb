# %%
import os,cv2,keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.layers import Dense
from keras import Model
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from keras.callbacks import ModelCheckpoint, EarlyStopping
import seaborn as sn
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve, RocCurveDisplay
from sklearn import metrics

# %%
img_path='C:/School/ECE539/Project/R-CNN/Data/Images'
annot_path='C:/School/ECE539/Project/R-CNN/Data/Annotations'

# img_path='./Data/Images'
# annot_path='./Data/Annotations'

# %%
for e,i in enumerate(os.listdir(annot_path)):
    if e < 10:
        filename = i.split(".")[0]+".jpg"
        print(filename)
        img = cv2.imread(os.path.join(img_path,filename))
        df = pd.read_csv(os.path.join(annot_path,i))
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        for row in df.iterrows():
            x1 = int(row[1][0].split(" ")[0])
            y1 = int(row[1][0].split(" ")[1])
            x2 = int(row[1][0].split(" ")[2])
            y2 = int(row[1][0].split(" ")[3])
            cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,0), 2)
        plt.figure()
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        break
# Out:
# apple_1.jpg

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
def get_iou(bb1, bb2):
    assert bb1['x1'] < bb1['x2']
    assert bb1['y1'] < bb1['y2']
    assert bb2['x1'] < bb2['x2']
    assert bb2['y1'] < bb2['y2']
    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])
    if x_right < x_left or y_bottom < y_top:
        return 0.0
    intersection_area = (x_right - x_left) * (y_bottom - y_top)
    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])
    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
train_images=[]
train_labels=[]
apple_count = 0
orange_count = 0
banana_count = 0
for e,i in enumerate(os.listdir(annot_path)):
    try:
        filename = i.split(".")[0]+".jpg"
        label_str = filename.split('_')[0]
        label_num = 0
        if label_str == 'apple':
            label_num = 1
        elif label_str == 'banana':
            label_num = 2   
        elif label_str == 'orange':
             label_num = 3
        elif label_str == 'mixed':
          continue
        image = cv2.imread(os.path.join(img_path,filename))
        df = pd.read_csv(os.path.join(annot_path,i))
        gtvalues=[]
        for row in df.iterrows():
            x1 = int(row[1][0].split(" ")[0])
            y1 = int(row[1][0].split(" ")[1])
            x2 = int(row[1][0].split(" ")[2])
            y2 = int(row[1][0].split(" ")[3])
            gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})
        ss.setBaseImage(image)
        ss.switchToSelectiveSearchFast()
        ssresults = ss.process()
        imout = image.copy()
        # plt.imshow(imout)
        # break
        counter = 0
        falsecounter = 0
        flag = 0
        fflag = 0
        bflag = 0
        for e,result in enumerate(ssresults):
            if e < 2000 and flag == 0:
                for gtval in gtvalues:
                    x,y,w,h = result
                    iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                    if counter < 30:
                        if iou > 0.75:
                            timage = imout[y:y+h,x:x+w]
                            resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                            train_images.append(resized)
                            train_labels.append(label_num)
                            counter += 1
                    else :
                        fflag =1
                    if falsecounter <30:
                        if iou < 0.3:
                            timage = imout[y:y+h,x:x+w]
                            resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                            train_images.append(resized)
                            train_labels.append(0)
                            falsecounter += 1
                    else :
                        bflag = 1
                if fflag == 1 and bflag == 1:
                    #print("inside")
                    flag = 1
    except Exception as e:
        print(e)
        print("error in "+filename)
        continue

# %%
X_new = np.array(train_images)
y_new = np.array(train_labels)

print(X_new.shape)
print(y_new.shape)
# Out:
# (12224, 224, 224, 3)
# (12224,)

# %%
# TODO use resnet50 instead of vgg16
vggmodel = VGG16(weights='imagenet', include_top=True)
vggmodel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layers in (vggmodel.layers)[:15]:
    print(layers)
    layers.trainable = False
# Out:
# <keras.engine.input_layer.InputLayer object at 0x000001C9E2FFD480>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001C9E2FF0310>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001C9E2FF0400>
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001C9E2FC7DC0>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001C9E2FF04F0>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001C9E2FC71F0>
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001C9D60F9960>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001C9E0F09C30>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001C986685600>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001C986685FC0>
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001C9866872E0>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001C986686F20>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001C986687EB0>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001C986687B80>
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001C9866A17E0>

# %%
X= vggmodel.layers[-2].output

# %%
# predictions = Dense(2, activation="softmax")(X)
predictions = Dense(4, activation="softmax")(X)

# %%
model_final = Model(vggmodel.input, predictions)

# %%
opt = Adam(learning_rate=0.0001)

# %%
model_final.compile(loss = keras.losses.categorical_crossentropy, optimizer = opt, metrics=["accuracy"])

# %%
model_final.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense (Dense)               (None, 4)                 16388
#
# =================================================================
# Total params: 134,276,932
# Trainable params: 126,641,668
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)

# %%
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(y_new)

# %%
X_train, X_test , y_train, y_test = train_test_split(X_new,Y,test_size=0.10)
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (11001, 224, 224, 3) (1223, 224, 224, 3) (11001, 4) (1223, 4)

# %%
trdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
traindata = trdata.flow(x=X_train, y=y_train)
tsdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
testdata = tsdata.flow(x=X_test, y=y_test)

# %%
checkpoint = ModelCheckpoint("ieeercnn_vgg16_1.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
hist = model_final.fit_generator(generator= traindata, steps_per_epoch= 10, epochs= 50, validation_data= testdata, validation_steps=2, callbacks=[checkpoint,early])
# Out:
# C:\Users\Xurso\AppData\Local\Temp\ipykernel_18416\3247725977.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model_final.fit_generator(generator= traindata, steps_per_epoch= 10, epochs= 50, validation_data= testdata, validation_steps=2, callbacks=[checkpoint,early])
# Epoch 1/50
# 10/10 [==============================] - ETA: 0s - loss: 0.7753 - accuracy: 0.8094
# Epoch 1: val_loss improved from inf to 0.14800, saving model to ieeercnn_vgg16_1.h5
# 10/10 [==============================] - 78s 7s/step - loss: 0.7753 - accuracy: 0.8094 - val_loss: 0.1480 - val_accuracy: 0.9219
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9469
# Epoch 2: val_loss improved from 0.14800 to 0.03561, saving model to ieeercnn_vgg16_1.h5
# 10/10 [==============================] - 67s 7s/step - loss: 0.1985 - accuracy: 0.9469 - val_loss: 0.0356 - val_accuracy: 1.0000
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2123 - accuracy: 0.9406
# Epoch 3: val_loss did not improve from 0.03561
# 10/10 [==============================] - 57s 6s/step - loss: 0.2123 - accuracy: 0.9406 - val_loss: 0.0716 - val_accuracy: 0.9531
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9469
# Epoch 4: val_loss did not improve from 0.03561
# 10/10 [==============================] - 58s 6s/step - loss: 0.1596 - accuracy: 0.9469 - val_loss: 0.0724 - val_accuracy: 0.9688
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9688
# Epoch 5: val_loss did not improve from 0.03561
# 10/10 [==============================] - 57s 6s/step - loss: 0.1019 - accuracy: 0.9688 - val_loss: 0.0905 - val_accuracy: 0.9531
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1910 - accuracy: 0.9469
# Epoch 6: val_loss did not improve from 0.03561
# 10/10 [==============================] - 58s 6s/step - loss: 0.1910 - accuracy: 0.9469 - val_loss: 0.1626 - val_accuracy: 0.9219
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2420 - accuracy: 0.9469
# Epoch 7: val_loss did not improve from 0.03561
# 10/10 [==============================] - 59s 6s/step - loss: 0.2420 - accuracy: 0.9469 - val_loss: 0.1684 - val_accuracy: 0.9375
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2041 - accuracy: 0.9469
# Epoch 8: val_loss did not improve from 0.03561
# 10/10 [==============================] - 59s 6s/step - loss: 0.2041 - accuracy: 0.9469 - val_loss: 0.0929 - val_accuracy: 0.9688
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9594
# Epoch 9: val_loss did not improve from 0.03561
# 10/10 [==============================] - 64s 6s/step - loss: 0.1122 - accuracy: 0.9594 - val_loss: 0.1250 - val_accuracy: 0.9688
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 0.9594
# Epoch 10: val_loss improved from 0.03561 to 0.01989, saving model to ieeercnn_vgg16_1.h5
# 10/10 [==============================] - 74s 7s/step - loss: 0.1001 - accuracy: 0.9594 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2067 - accuracy: 0.9438
# Epoch 11: val_loss did not improve from 0.01989
# 10/10 [==============================] - 56s 6s/step - loss: 0.2067 - accuracy: 0.9438 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9688
# Epoch 12: val_loss did not improve from 0.01989
# 10/10 [==============================] - 57s 6s/step - loss: 0.1073 - accuracy: 0.9688 - val_loss: 0.0439 - val_accuracy: 0.9844
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9500
# Epoch 13: val_loss did not improve from 0.01989
# 10/10 [==============================] - 58s 6s/step - loss: 0.1160 - accuracy: 0.9500 - val_loss: 0.1286 - val_accuracy: 0.9688
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1575 - accuracy: 0.9656
# Epoch 14: val_loss did not improve from 0.01989
# 10/10 [==============================] - 58s 6s/step - loss: 0.1575 - accuracy: 0.9656 - val_loss: 0.2592 - val_accuracy: 0.9375
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 0.9844
# Epoch 15: val_loss did not improve from 0.01989
# 10/10 [==============================] - 59s 6s/step - loss: 0.0410 - accuracy: 0.9844 - val_loss: 0.0413 - val_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9750
# Epoch 16: val_loss did not improve from 0.01989
# 10/10 [==============================] - 58s 6s/step - loss: 0.0621 - accuracy: 0.9750 - val_loss: 0.3114 - val_accuracy: 0.9375
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.9531
# Epoch 17: val_loss did not improve from 0.01989
# 10/10 [==============================] - 57s 6s/step - loss: 0.2322 - accuracy: 0.9531 - val_loss: 0.0929 - val_accuracy: 0.9531
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1423 - accuracy: 0.9469
# Epoch 18: val_loss did not improve from 0.01989
# 10/10 [==============================] - 58s 6s/step - loss: 0.1423 - accuracy: 0.9469 - val_loss: 0.0694 - val_accuracy: 0.9688
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9719
# Epoch 19: val_loss did not improve from 0.01989
# 10/10 [==============================] - 58s 6s/step - loss: 0.1243 - accuracy: 0.9719 - val_loss: 0.0319 - val_accuracy: 0.9844
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.9625
# Epoch 20: val_loss did not improve from 0.01989
# 10/10 [==============================] - 60s 6s/step - loss: 0.1355 - accuracy: 0.9625 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9812
# Epoch 21: val_loss did not improve from 0.01989
# 10/10 [==============================] - 58s 6s/step - loss: 0.0688 - accuracy: 0.9812 - val_loss: 0.0645 - val_accuracy: 0.9844
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9844
# Epoch 22: val_loss improved from 0.01989 to 0.00462, saving model to ieeercnn_vgg16_1.h5
# 10/10 [==============================] - 64s 7s/step - loss: 0.0488 - accuracy: 0.9844 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9750
# Epoch 23: val_loss did not improve from 0.00462
# 10/10 [==============================] - 57s 6s/step - loss: 0.1230 - accuracy: 0.9750 - val_loss: 0.1307 - val_accuracy: 0.9844
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1173 - accuracy: 0.9750
# Epoch 24: val_loss did not improve from 0.00462
# 10/10 [==============================] - 57s 6s/step - loss: 0.1173 - accuracy: 0.9750 - val_loss: 0.0632 - val_accuracy: 0.9844
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9688
# Epoch 25: val_loss did not improve from 0.00462
# 10/10 [==============================] - 60s 6s/step - loss: 0.1349 - accuracy: 0.9688 - val_loss: 0.1393 - val_accuracy: 0.9688
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9688
# Epoch 26: val_loss did not improve from 0.00462
# 10/10 [==============================] - 61s 6s/step - loss: 0.0746 - accuracy: 0.9688 - val_loss: 0.1384 - val_accuracy: 0.9375
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1183 - accuracy: 0.9594
# Epoch 27: val_loss did not improve from 0.00462
# 10/10 [==============================] - 60s 6s/step - loss: 0.1183 - accuracy: 0.9594 - val_loss: 0.0998 - val_accuracy: 0.9688
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9625
# Epoch 28: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.1133 - accuracy: 0.9625 - val_loss: 0.0931 - val_accuracy: 0.9688
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9625
# Epoch 29: val_loss did not improve from 0.00462
# 10/10 [==============================] - 59s 6s/step - loss: 0.0849 - accuracy: 0.9625 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0638 - accuracy: 0.9812
# Epoch 30: val_loss did not improve from 0.00462
# 10/10 [==============================] - 59s 6s/step - loss: 0.0638 - accuracy: 0.9812 - val_loss: 0.0619 - val_accuracy: 0.9844
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0685 - accuracy: 0.9719
# Epoch 31: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.0685 - accuracy: 0.9719 - val_loss: 0.1147 - val_accuracy: 0.9844
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9656
# Epoch 32: val_loss did not improve from 0.00462
# 10/10 [==============================] - 57s 6s/step - loss: 0.1060 - accuracy: 0.9656 - val_loss: 0.0623 - val_accuracy: 0.9844
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9688
# Epoch 33: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.0938 - accuracy: 0.9688 - val_loss: 0.0949 - val_accuracy: 0.9688
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9656
# Epoch 34: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.0889 - accuracy: 0.9656 - val_loss: 0.1715 - val_accuracy: 0.9844
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0716 - accuracy: 0.9719
# Epoch 35: val_loss did not improve from 0.00462
# 10/10 [==============================] - 57s 6s/step - loss: 0.0716 - accuracy: 0.9719 - val_loss: 0.0420 - val_accuracy: 0.9844
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9875
# Epoch 36: val_loss did not improve from 0.00462
# 10/10 [==============================] - 59s 6s/step - loss: 0.0550 - accuracy: 0.9875 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9750
# Epoch 37: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.0649 - accuracy: 0.9750 - val_loss: 0.0569 - val_accuracy: 0.9844
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9531
# Epoch 38: val_loss did not improve from 0.00462
# 10/10 [==============================] - 57s 6s/step - loss: 0.2058 - accuracy: 0.9531 - val_loss: 0.0388 - val_accuracy: 1.0000
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1120 - accuracy: 0.9719
# Epoch 39: val_loss did not improve from 0.00462
# 10/10 [==============================] - 59s 6s/step - loss: 0.1120 - accuracy: 0.9719 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1790 - accuracy: 0.9625
# Epoch 40: val_loss did not improve from 0.00462
# 10/10 [==============================] - 59s 6s/step - loss: 0.1790 - accuracy: 0.9625 - val_loss: 0.0512 - val_accuracy: 0.9844
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9844
# Epoch 41: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.0560 - accuracy: 0.9844 - val_loss: 0.0991 - val_accuracy: 0.9688
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9625
# Epoch 42: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.1067 - accuracy: 0.9625 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1684 - accuracy: 0.9500
# Epoch 43: val_loss did not improve from 0.00462
# 10/10 [==============================] - 59s 6s/step - loss: 0.1684 - accuracy: 0.9500 - val_loss: 0.1306 - val_accuracy: 0.9062
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9656
# Epoch 44: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.0928 - accuracy: 0.9656 - val_loss: 0.0394 - val_accuracy: 0.9844
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1257 - accuracy: 0.9625
# Epoch 45: val_loss did not improve from 0.00462
# 10/10 [==============================] - 57s 6s/step - loss: 0.1257 - accuracy: 0.9625 - val_loss: 0.0412 - val_accuracy: 0.9844
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0808 - accuracy: 0.9781
# Epoch 46: val_loss did not improve from 0.00462
# 10/10 [==============================] - 59s 6s/step - loss: 0.0808 - accuracy: 0.9781 - val_loss: 0.1380 - val_accuracy: 0.9688
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0929 - accuracy: 0.9750
# Epoch 47: val_loss did not improve from 0.00462
# 10/10 [==============================] - 59s 6s/step - loss: 0.0929 - accuracy: 0.9750 - val_loss: 0.0322 - val_accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9781
# Epoch 48: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.0714 - accuracy: 0.9781 - val_loss: 0.0490 - val_accuracy: 0.9688
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0864 - accuracy: 0.9688
# Epoch 49: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.0864 - accuracy: 0.9688 - val_loss: 0.1189 - val_accuracy: 0.9688
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9531
# Epoch 50: val_loss did not improve from 0.00462
# 10/10 [==============================] - 58s 6s/step - loss: 0.0968 - accuracy: 0.9531 - val_loss: 0.0586 - val_accuracy: 0.9688

# %%
# plt.plot(hist.history["acc"])
# plt.plot(hist.history['val_acc'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Loss","Validation Loss"])
plt.show()
plt.savefig('chart loss.png')

# %%
im = X_test[140]
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
img = np.expand_dims(im, axis=0)
out= model_final.predict(img)
img_class = max(out[0])
pred_label = list(out[0]).index(img_class)
if pred_label == 0:
    print("Not a fruit")
elif pred_label == 1:
    print('apple')
elif pred_label == 2:
    print("banana")
elif pred_label == 3:
    print('orange')
# if out[0][0] > out[0][1]:
#     print("Fruit")
# else:
#     print("Not Fruit")
# Out:
# 1/1 [==============================] - 0s 354ms/step
# Not a fruit

# %%
# z=0
# for e,i in enumerate(os.listdir(img_path)):
  
#     if i.startswith("mixed_5"):
#         z += 1
#         img = cv2.imread(os.path.join(img_path,i))
#         ss.setBaseImage(img)
#         ss.switchToSelectiveSearchFast()
#         ssresults = ss.process()
#         imout = img.copy()
#         for e,result in enumerate(ssresults):
#             if e < 2000:
#                 x,y,w,h = result
#                 timage = imout[y:y+h,x:x+w]
#                 resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
#                 img = np.expand_dims(resized, axis=0)
#                 out= model_final.predict(img)
#                 if out[0][1] > 0.7 or  out[0][2] > 0.7 or  out[0][3] > 0.7:
#                     cv2.rectangle(imout, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
#         plt.figure()
#         plt.imshow(cv2.cvtColor(imout, cv2.COLOR_BGR2RGB))

# %%
# You can visualize the results with a confusion matrix.
def plot_confusion_matrix(y_classified, y_true):
  # Compute confusion matrix
    c_mat = np.zeros((y_test.shape[1],y_test.shape[1]))
    for i in range(len(y_true)):
        c_mat[y_classified[i], y_true[i] ] += 1

    group_counts = ["{0:0.0f}".format(value) for value in c_mat.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in c_mat.flatten()/np.sum(c_mat)]
    labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(c_mat.shape[0], c_mat.shape[1])

    plt.figure(figsize=(12,10))
    sn.heatmap(c_mat, annot=labels, fmt='', cmap='rocket_r')
    plt.title("Confusion Matrix")
    plt.ylabel('Output Class')
    plt.xlabel('Target Class')

# %%
# Evaluate the trained model using keras built-in function
score = model_final.evaluate(X_test, y_test, verbose=1)
print("Test loss:", score[0])
print("Test accuracy:", score[1]) 

y_classified = np.argmax(model_final.predict(X_test), axis=1)
y_true =  np.argmax(y_test, axis=1)
# Compute the confusion matrix
print("Confusion matrix: \n", confusion_matrix(y_true, y_classified))

# plot confusion matrix
plot_confusion_matrix(y_classified, y_true)
# Out:
# 39/39 [==============================] - 139s 4s/step - loss: 0.0617 - accuracy: 0.9804
# Test loss: 0.061652570962905884
# Test accuracy: 0.980376124382019
# 39/39 [==============================] - 140s 4s/step
# Confusion matrix:
#  [[815   3   0   6]
#  [  2 144   0   0]
#  [ 12   0 116   1]
#  [  0   0   0 124]]

# %%
plt.figure(figsize = (16, 10))
classes = ['None','Apple', 'Banana', 'Orange']

for i in range(len(classes)):
    y_true_sub = np.array([int(y == i) for y in y_true])
    y_class_sub = np.array([int(y == i) for y in y_classified])
    
    roc_auc = metrics.roc_auc_score(y_true_sub,y_class_sub)

    ax = plt.subplot(2, 3, i+1)
    ax.set_title(classes[i])
    ax.legend([f"Class: {classes[i]}", "Rest"])
    ax.set_xlabel(f"P(x = {classes[i]})")

    # Calculates the ROC Coordinates and plots the ROC Curves
    fpr, tpr, threshold = metrics.roc_curve(y_true_sub, y_class_sub)
    #plot_roc_curve(tpr, fpr, scatter = False, ax = ax_bottom)
    RocCurveDisplay.from_predictions(y_true_sub, y_class_sub, ax = ax)
    ax.set_title(f"ROC Curve {classes[i]} v Rest")

# %%
metrics.matthews_corrcoef(y_true, y_classified, sample_weight=None)
# Out:
# 0.9615420920730929
