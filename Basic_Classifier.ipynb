# %%
# Importing modules 
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf

from keras.utils import to_categorical
from keras.layers import Conv2D,MaxPooling2D,BatchNormalization,Activation,Dense,Flatten
from keras.models import Sequential

from sklearn.model_selection import train_test_split

np.random.seed(1)

# %%
train_images = []       
train_labels = []
shape = (200,200)  
train_path = "C:\School\ECE539\Project\\train\\train"

for filename in os.listdir(train_path):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(train_path,filename))
        
        # Spliting file names and storing the labels for image in list
        train_labels.append(filename.split('_')[0])
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
        
        train_images.append(img)
train_labels = pd.get_dummies(train_labels).values

# Converting train_images to array
train_images = np.array(train_images)

# Splitting Training data into train and validation dataset
X_train,X_val,y_train,y_val = train_test_split(train_images,train_labels,random_state=1)

# %%
test_images = []
test_labels = []
shape = (200,200)
test_path = "C:\School\ECE539\Project\\test\\test"

for filename in os.listdir(test_path):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(test_path,filename))
        
        # Spliting file names and storing the labels for image in list
        test_labels.append(filename.split('_')[0])
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
        
        test_images.append(img)
        
# Converting test_images to array
X_test = np.array(test_images)
y_test = pd.get_dummies(test_labels).values

# %%
print('Train: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Val  : X=%s, y=%s' % (X_val.shape, y_val.shape))
print('Test : X=%s, y=%s' % (X_test.shape, y_test.shape))
# Out:
# Train: X=(180, 200, 200, 3), y=(180, 4)
# Val  : X=(60, 200, 200, 3), y=(60, 4)
# Test : X=(60, 200, 200, 3), y=(60, 4)

# %%
# net = Sequential()
# net.add(Conv2D(32, (3, 3), padding='same', input_shape=(200, 200, 3)))
# net.add(BatchNormalization())
# net.add(Activation('relu'))

# net.add(MaxPooling2D((2, 2),strides=2))

# net.add(Conv2D(30, (3, 3), padding='same'))
# net.add(BatchNormalization())
# net.add(Activation('relu'))

# net.add(MaxPooling2D((2, 2),strides=2))

# net.add(Conv2D(30, (3, 3), padding='same'))
# net.add(BatchNormalization())
# net.add(Activation('relu'))

# net.add(Flatten())
# net.add(Dense(4, activation='softmax'))

# %%
# Creating a Sequential model
net= Sequential()
net.add(Conv2D(kernel_size=(3,3), filters=32, activation='tanh', input_shape=(200,200,3,)))
net.add(Conv2D(filters=30,kernel_size = (3,3),activation='tanh'))
net.add(MaxPooling2D(2,2))
net.add(Conv2D(filters=30,kernel_size = (3,3),activation='tanh'))
net.add(MaxPooling2D(2,2))
net.add(Conv2D(filters=30,kernel_size = (3,3),activation='tanh'))

net.add(Flatten())

net.add(Dense(20,activation='relu'))
net.add(Dense(15,activation='relu'))
net.add(Dense(4,activation = 'softmax'))

net.compile(
              loss='categorical_crossentropy', 
              metrics=['acc'],
              optimizer='adam'
             )

# %%
net.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 196, 196, 30)      8670
#
#  max_pooling2d (MaxPooling2D  (None, 98, 98, 30)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 30)        8130
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 30)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 30)        8130
#
#  flatten (Flatten)           (None, 63480)             0
#
#  dense (Dense)               (None, 20)                1269620
#
#  dense_1 (Dense)             (None, 15)                315
#
#  dense_2 (Dense)             (None, 4)                 64
#
# =================================================================
# Total params: 1,295,825
# Trainable params: 1,295,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = net.fit(X_train,y_train,epochs=50,batch_size=50,validation_data=(X_val,y_val))
# Out:
# Epoch 1/50
# 4/4 [==============================] - 14s 3s/step - loss: 3.1675 - acc: 0.3056 - val_loss: 5.9428 - val_acc: 0.3000
# Epoch 2/50
# 4/4 [==============================] - 12s 3s/step - loss: 5.6870 - acc: 0.3111 - val_loss: 6.9971 - val_acc: 0.2833
# Epoch 3/50
# 4/4 [==============================] - 13s 3s/step - loss: 4.2746 - acc: 0.3056 - val_loss: 1.5808 - val_acc: 0.4000
# Epoch 4/50
# 4/4 [==============================] - 13s 3s/step - loss: 1.8603 - acc: 0.3500 - val_loss: 2.0542 - val_acc: 0.3500
# Epoch 5/50
# 4/4 [==============================] - 8s 2s/step - loss: 1.5693 - acc: 0.4000 - val_loss: 1.4760 - val_acc: 0.5333
# Epoch 6/50
# 4/4 [==============================] - 8s 2s/step - loss: 1.1225 - acc: 0.4444 - val_loss: 1.5922 - val_acc: 0.5167
# Epoch 7/50
# 4/4 [==============================] - 8s 2s/step - loss: 1.1756 - acc: 0.5333 - val_loss: 1.1325 - val_acc: 0.5833
# Epoch 8/50
# 4/4 [==============================] - 12s 3s/step - loss: 1.1952 - acc: 0.4000 - val_loss: 1.0763 - val_acc: 0.4500
# Epoch 9/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.9175 - acc: 0.5389 - val_loss: 0.8186 - val_acc: 0.6667
# Epoch 10/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.7619 - acc: 0.7111 - val_loss: 0.6396 - val_acc: 0.7667
# Epoch 11/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.7943 - acc: 0.6833 - val_loss: 0.4991 - val_acc: 0.8500
# Epoch 12/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.5525 - acc: 0.7667 - val_loss: 0.5753 - val_acc: 0.8167
# Epoch 13/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.5033 - acc: 0.8556 - val_loss: 0.3619 - val_acc: 0.8500
# Epoch 14/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.3628 - acc: 0.8611 - val_loss: 0.4089 - val_acc: 0.8667
# Epoch 15/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3741 - acc: 0.8611 - val_loss: 0.4921 - val_acc: 0.8333
# Epoch 16/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.3261 - acc: 0.8722 - val_loss: 0.4206 - val_acc: 0.8667
# Epoch 17/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2576 - acc: 0.9111 - val_loss: 0.4142 - val_acc: 0.8500
# Epoch 18/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2288 - acc: 0.9167 - val_loss: 0.4253 - val_acc: 0.8667
# Epoch 19/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2009 - acc: 0.9222 - val_loss: 0.3703 - val_acc: 0.8833
# Epoch 20/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.1843 - acc: 0.9389 - val_loss: 0.3717 - val_acc: 0.8500
# Epoch 21/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.1856 - acc: 0.9500 - val_loss: 0.3845 - val_acc: 0.8833
# Epoch 22/50
# 4/4 [==============================] - 12s 3s/step - loss: 0
50
# 4/4 [==============================] - 12s 3s/step - loss: 0.0359 - acc: 0.9944 - val_loss: 0.9501 - val_acc: 0.8500
# Epoch 49/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.0317 - acc: 0.9944 - val_loss: 0.9144 - val_acc: 0.8500
# Epoch 50/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.0295 - acc: 1.0000 - val_loss: 0.8930 - val_acc: 0.8500

# %%
# # Hyperparameters
# lr = 0.1
# mom = 0.9 
# ep = 10
# bs = 100

# %%
# # compile and fit the keras model
# # from tensorflow.keras.optimizers import SGD
# # opt = SGD(learning_rate=lr, momentum=mom)
# net.compile(loss='categorical_crossentropy', metrics=['accuracy'])


# # insert model check point call back
# checkpoint_filepath = 'tmp/checkpoint'
# model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=checkpoint_filepath,
#     save_weights_only=True,
#     monitor='val_accuracy',
#     mode='max',
#     save_best_only=True)
# # Model weights are saved at the end of every epoch, if it's the best seen
# # so far.
# history = net.fit(X_train, y_train, epochs=ep, batch_size=bs, validation_data=(X_val,y_val), verbose=1, callbacks=[model_checkpoint_callback])
# # The model weights (that are considered the best) are loaded into the model.
# net.load_weights(checkpoint_filepath)

# %%
# You can visualize the results with a confusion matrix.
import seaborn as sn
import numpy as np
import matplotlib.pyplot as plt
def plot_confusion_matrix(y_classified, y_true):
  # Compute confusion matrix
    c_mat = np.zeros((y_test.shape[1],y_test.shape[1]))
    for i in range(len(y_true)):
        c_mat[y_classified[i], y_true[i] ] += 1

    group_counts = ["{0:0.0f}".format(value) for value in c_mat.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in c_mat.flatten()/np.sum(c_mat)]
    labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(c_mat.shape[0], c_mat.shape[1])

    plt.figure(figsize=(12,10))
    sn.heatmap(c_mat, annot=labels, fmt='', cmap='rocket_r')
    plt.title("Confusion Matrix")
    plt.ylabel('Output Class')
    plt.xlabel('Target Class')

# %%
# Evaluate the trained model using keras built-in function
score = net.evaluate(X_test, y_test, verbose=1)
print("Test loss:", score[0])
print("Test accuracy:", score[1]) 

y_classified = np.argmax(net.predict(X_test), axis=1)
y_true =  np.argmax(y_test, axis=1)
# Compute the confusion matrix
from sklearn.metrics import confusion_matrix, accuracy_score
print("Confusion matrix: \n", confusion_matrix(y_true, y_classified))

# plot confusion matrix
plot_confusion_matrix(y_classified, y_true)
# Out:
# 2/2 [==============================] - 1s 430ms/step - loss: 1.3676 - acc: 0.8667
# Test loss: 1.3676170110702515
# Test accuracy: 0.8666666746139526
# 2/2 [==============================] - 1s 380ms/step
# Confusion matrix:
#  [[19  0  0  0]
#  [ 1 16  0  1]
#  [ 2  2  0  1]
#  [ 0  0  1 17]]

# %%
# Compute the confusion matrix
from sklearn.metrics import confusion_matrix, accuracy_score
print("Confusion matrix: \n", confusion_matrix(y_true, y_classified))
print("P(classification) =", np.round(accuracy_score(y_true, y_classified), 3))
# Out:
# Confusion matrix:
#  [[19  0  0  0]
#  [ 1 16  0  1]
#  [ 2  2  0  1]
#  [ 0  0  1 17]]
# P(classification) = 0.867
